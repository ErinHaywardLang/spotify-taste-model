# %%
# notebook_setup.py
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
import sys
sys.path
# Out:
# ['/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python311.zip',
#  '/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11',
#  '/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload',
#  '',
#  '/Users/erinhayward-lang/github/spotify-taste-model/venv/lib/python3.11/site-packages',
#  '/Users/erinhayward-lang/github/spotify-taste-model']

# %%
from src.spotify_client import get_spotify_client

sp = get_spotify_client()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.spotify_client import get_spotify_client
#       3 sp = get_spotify_client()
#
# ModuleNotFoundError: No module named 'src.spotify_client'

# %%
import os

os.listdir()
# Out:
# ['connect.ipynb', 'sample data [old]']

# %%
from pathlib import Path

Path.cwd()
# Out:
# PosixPath('/Users/erinhayward-lang/github/spotify-taste-model/notebooks')

# %%
Path.cwd().parent
# Out:
# PosixPath('/Users/erinhayward-lang/github/spotify-taste-model')

# %%
(Path.cwd().parent / "src").exists()
# Out:
# True

# %%
import os

os.listdir(Path.cwd().parent / "src")
# Out:
# ['spotify_client.py ', '__init__.py', '__pycache__']

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
str(project_root) in sys.path
# Out:
# True

# %%
import src
